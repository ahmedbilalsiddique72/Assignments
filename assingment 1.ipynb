# %% [markdown]
# TASK 1

# %%
student_name = "Ahmed bilal"
age =17
city = "Karachi"
student_status = "active"
print(student_name)
print(age)
print(city)
print(student_status)
# Out:
# Syed Mustafa Ali
# 17
# Karachi
# active

# %% [markdown]
# TASK 2

# %%
string = "Bilal"
integer = 87
float = 67.9
boolean = 9>3
print(string)
print(integer)
print(float)
print(boolean)
print(type(string))
print(type(integer))
print(type(float))
print(type(boolean))
# Out:
# Mustafa
# 87
# 67.9
# True
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>

# %% [markdown]
# TASK 3

# %%
number_1 = 10
number_2 = 12
print(number_1 + number_2)
print(number_1 - number_2)
print(number_1 * number_2)
print(number_1 / number_2)
print(number_1 % number_2)
print(number_1 ** number_2)
# Out:
# 22
# -2
# 120
# 0.8333333333333334
# 10
# 1000000000000

# %% [markdown]
# TASK 4

# %%
english = 97
maths = 80
physics = 75
total_marks = english+maths+physics
avg_marks= total_marks/3
print(total_marks)
print(avg_marks)
# Out:
# 252
# 84.0

# %% [markdown]
# TASK 5

# %%
product_price=400
quantity=5
total_price = product_price*quantity
print("Total price:",total_price)
# Out:
# Total price: 2000

# %% [markdown]
# Task 6

# %%
length = 20
width = 9
area=length*width
paremeter=2*(length+width)
print("Area is:",area,"cm³")
print("Paremeyter is:",paremeter,"cm")
# Out:
# Area is: 180 cm³
# Paremeyter is: 58 cm

# %% [markdown]
# TASK 7

# %%
minutes=250
hour=minutes//60
remaning_minutes= minutes%60
print(f"{hour} Hours and {remaning_minutes} minutes")
# Out:
# 4 Hours and 10 minutes

# %% [markdown]
# TASK 8

# %%
marks=76
attendance= 92
if marks>=50 and attendance >=75:
    print("You are eligible")
else:
    print("You are not eligible")
# Out:
# You are eligible

# %% [markdown]
# TASK 9

# %%
a = 10>8
b = 8>10
print(a and b)
print(a or b)
print(not a and b)
print(not b or a)
# Out:
# False
# True
# False
# True

# %% [markdown]
# Final challenge

# %%
student_name= "BIalal"
age = 17
marks_english= 75
marks_maths= 80
marks_computer= 92
attendace= 85
total_marks= marks_english+marks_computer+marks_maths
avg_marks= total_marks//3
eligible= avg_marks>50 and attendace>=75
print(student_name)
print(age)
print("Total Marks:",total_marks)
print("Average Marks:",avg_marks)
print("Attendance:",attendance,"%")
print("Eligibility:",eligible)
# Out:
# Mustafa
# 17
# Total Marks: 247
# Average Marks: 82
# Attendance: 92 %
# Eligibility: True
